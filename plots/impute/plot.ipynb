# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

my_method_name = "GPC"

# --- Settings ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])  # For plotting

all_methods = ['real_8020', 'pc_real_8020', 'hclt_8020', 'rbm_8020', 'wgan_8020', 'rbm_full', 'wgan_full']
all_colors = ['black', 'dodgerblue', 'b', 'orange', 'g', 'navajowhite', 'lightgreen']
all_markers = ['o', 's', 's', '^', 'D', '^', 'D']
all_labels = ['Impute5', f'{my_method_name} (direct)', f'{my_method_name}', 'RBM', 'WGAN', 'RBM (full)', 'WGAN (full)']
all_linestyles = ['--', '-', '-', '-', '-', '-', '-']

# --- Function to summarize bootstrap statistics ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/r2/{method}_8020.csv')

    # Remove variants with MAF=0 upfront
    df = df[df['MAF'] > 0].copy()

    r2_cols = [c for c in df.columns if c.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)

    # Identify bootstrap columns
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]

    print(f"Method: {method}")

    # Full summary
    summarize_bootstrap(df, boot_cols, "Full set")

    # Low-frequency and rare subsets
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

    method_data[method] = df

# --- Plot each method with CI bands ---
plt.figure(figsize=(8,6))

for method_name, color, marker, label, linestyle in zip(all_methods, all_colors, all_markers, all_labels, all_linestyles):
    df = method_data[method_name]

    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]

    # Digitize MAFs into bins
    bin_indices = np.digitize(df['MAF'], bins) - 1

    mean_r2 = []
    ci_low = []
    ci_high = []

    for i in range(num_bins):
        in_bin = bin_indices == i
        if not np.any(in_bin):
            mean_r2.append(np.nan)
            ci_low.append(np.nan)
            ci_high.append(np.nan)
            continue
        boot_values = df.loc[in_bin, boot_cols].values
        bin_means = np.nanmean(boot_values, axis=0)
        mean = np.mean(bin_means)
        mean_r2.append(mean)
        ci_low.append(np.percentile(bin_means, 2.5))
        ci_high.append(np.percentile(bin_means, 97.5))

    mean_r2 = np.array(mean_r2)
    ci_low = np.array(ci_low)
    ci_high = np.array(ci_high)

    plt.plot(bin_centers, mean_r2, marker=marker, linestyle=linestyle, color=color, label=label)
    plt.fill_between(bin_centers, ci_low, ci_high, color=color, alpha=0.2)

# --- Plot formatting ---
plt.xscale('log')
plt.xticks([1e-4, 1e-3, 1e-2, 1e-1], [r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('MAF', fontsize=18)
plt.ylabel(r'Average $r^2$', fontsize=18)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=14)
plt.tight_layout()
plt.savefig("results/plots/8020_bootstrap_ci.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Method: real_8020
#   Full set Mean R²: 0.6489
#   Full set 95% CI: [0.6432, 0.6546]
#   Low-freq (<1%) Mean R²: 0.2976
#   Low-freq (<1%) 95% CI: [0.2856, 0.3095]
#   Rare (<0.1%) Mean R²: 0.0886
#   Rare (<0.1%) 95% CI: [0.0780, 0.0993]
# Method: pc_real_8020
#   Full set Mean R²: 0.5934
#   Full set 95% CI: [0.5886, 0.5983]
#   Low-freq (<1%) Mean R²: 0.2183
#   Low-freq (<1%) 95% CI: [0.2083, 0.2282]
#   Rare (<0.1%) Mean R²: 0.0529
#   Rare (<0.1%) 95% CI: [0.0444, 0.0613]
# Method: hclt_8020
#   Full set Mean R²: 0.5403
#   Full set 95% CI: [0.5362, 0.5445]
#   Low-freq (<1%) Mean R²: 0.1317
#   Low-freq (<1%) 95% CI: [0.1230, 0.1403]
#   Rare (<0.1%) Mean R²: 0.0124
#   Rare (<0.1%) 95% CI: [0.0082, 0.0166]
# Method: rbm_8020
#   Full set Mean R²: 0.4936
#   Full set 95% CI: [0.4910, 0.4963]
#   Low-freq (<1%) Mean R²: 0.0657
#   Low-freq (<1%) 95% CI: [0.0596, 0.0719]
#   Rare (<0.1%) Mean R²: 0.0069
#   Rare (<0.1%) 95% CI: [0.0045, 0.0092]
# Method: wgan_8020
#   Full set Mean R²: 0.4451
#   Full set 95% CI: [0.4431, 0.4471]
#   Low-freq (<1%) Mean R²: 0.0093
#   Low-freq (<1%) 95% CI: [0.0085, 0.0100]
#   Rare (<0.1%) Mean R²: 0.0006
#   Rare (<0.1%) 95% CI: [0.0003, 0.0008]
# Method: rbm_full
#   Full set Mean R²: 0.5096
#   Full set 95% CI: [0.5057, 0.5135]
#   Low-freq (<1%) Mean R²: 0.0954
#   Low-freq (<1%) 95% CI: [0.0875, 0.1033]
#   Rare (<0.1%) Mean R²: 0.0119
#   Rare (<0.1%) 95% CI: [0.0073, 0.0166]
# Method: wgan_full
#   Full set Mean R²: 0.4281
#   Full set 95% CI: [0.4262, 0.4300]
#   Low-freq (<1%) Mean R²: 0.0042
#   Low-freq (<1%) 95% CI: [0.0035, 0.0050]
#   Rare (<0.1%) Mean R²: 0.0001
#   Rare (<0.1%) 95% CI: [0.0000, 0.0002]

# %%
# --- Slides: 1KG 8020 bar plot (RBM, WGAN, GPC, GPC direct) ---

slides_methods = ['rbm_8020', 'wgan_8020', 'pc_real_8020']
slides_colors  = ['orange', 'green', 'blue']
slides_labels  = ['RBM', 'WGAN', 'GPC']

bar_categories = ['Rare', 'Low-freq', 'All']
maf_filters_sl = [
    lambda df: df['MAF'] < 0.001,
    lambda df: df['MAF'] < 0.01,
    lambda df: df['MAF'] > 0,
]

n_cats_sl    = len(bar_categories)
n_methods_sl = len(slides_methods)
bar_width_sl = 0.18
x_sl = np.arange(n_cats_sl)

fig_sl, ax_sl = plt.subplots(figsize=(9, 6))

for ji, (method, color, label) in enumerate(zip(slides_methods, slides_colors, slides_labels)):
    df = method_data[method]
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
    means_sl, sems_sl = [], []
    for filt in maf_filters_sl:
        subset = df[filt(df)]
        if subset.empty:
            means_sl.append(0); sems_sl.append(0); continue
        boot_means = subset[boot_cols].mean(skipna=True)
        means_sl.append(boot_means.mean())
        sems_sl.append(boot_means.std(ddof=1))
    offset = (ji - (n_methods_sl - 1) / 2) * bar_width_sl
    ax_sl.bar(x_sl + offset, means_sl, bar_width_sl, color=color, label=label,
              yerr=sems_sl, capsize=4, error_kw=dict(linewidth=1.5))
    for xi, (mean, sem) in enumerate(zip(means_sl, sems_sl)):
        ax_sl.text(xi + offset, mean + sem + 0.012, f'{mean:.2f}',
                   ha='center', va='bottom', fontsize=9, color='#333333')

ax_sl.set_xlabel("SNP frequency", fontsize=18)
ax_sl.set_xticks(x_sl)
ax_sl.set_xticklabels(bar_categories, fontsize=16)
ax_sl.tick_params(axis='y', labelsize=15)
ax_sl.set_ylabel(r'Average $r^2$', fontsize=18)
ax_sl.set_ylim(0, None)
ax_sl.legend(fontsize=15, frameon=False, loc='upper left')
ax_sl.spines['top'].set_visible(False)
ax_sl.spines['right'].set_visible(False)
ax_sl.yaxis.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
ax_sl.set_axisbelow(True)

plt.tight_layout()
plt.savefig('results/plots/8020_bootstrap_ci_slides.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])

all_methods = [
    'real_noneur', 'pc_real_noneur', 'pc_realeur_and_noneur_train_noneur',
    'hclt_noneur', 'rbm_noneur', 'wgan_noneur',
    'hclt_noneur_combined', 'rbm_noneur_combined', 'wgan_noneur_combined' 
]
all_colors = ['black', 'dodgerblue', 'dodgerblue', 'b', 'orange', 'g', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', 's', '^', 'D', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', f'{my_method_name} (direct)',
    f'{my_method_name}', 'RBM', 'WGAN',
    f'{my_method_name}', 'RBM', 'WGAN'
]
all_linestyles = ['--', '-', '-', '-', '-', '-', '-', '-', '-']

baseline_indices = [0, 1, 3, 4, 5]
combined_indices = [0, 2, 6, 7, 8]

# --- Function to summarize bootstrap stats ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load and filter data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/r2/{method}_noneur.csv')
    df = df[df['MAF'] > 0].copy()  # remove MAF=0 variants
    r2_cols = [c for c in df.columns if c.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]

    print(f"Method: {method}")
    summarize_bootstrap(df, boot_cols, "Full set")
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

    method_data[method] = df

# --- Plotting function ---
def plot_methods(indices, title, filename):
    fig, ax = plt.subplots(figsize=(8,6))
    for idx in indices:
        method_name = all_methods[idx]
        df = method_data[method_name]
        boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
        bin_indices = np.digitize(df['MAF'], bins) - 1

        mean_r2, ci_low, ci_high = [], [], []

        for i in range(num_bins):
            in_bin = bin_indices == i
            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            mean = np.mean(bin_means)
            mean_r2.append(mean)
            ci_low.append(np.percentile(bin_means, 2.5))
            ci_high.append(np.percentile(bin_means, 97.5))

        mean_r2 = np.array(mean_r2)
        ci_low = np.array(ci_low)
        ci_high = np.array(ci_high)

        ax.plot(bin_centers, mean_r2, marker=all_markers[idx], linestyle=all_linestyles[idx],
                color=all_colors[idx], label=all_labels[idx])
        ax.fill_between(bin_centers, ci_low, ci_high, color=all_colors[idx], alpha=0.2)

    ax.set_xscale('log')
    ax.set_xticks([1e-4, 1e-3, 1e-2, 1e-1])
    ax.set_xticklabels([r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
    ax.set_yticks(np.linspace(0, 1, 6))
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax.set_ylabel(r'Average $r^2$', fontsize=18)
    ax.set_xlabel('MAF', fontsize=18)
    # ax.set_title(title, fontsize=18)
    ax.legend(fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, format="pdf", dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Generate plots ---
plot_methods(baseline_indices, 'Non EUR AGs', 'results/plots/noneur_bootstrap_baseline.pdf')
plot_methods(combined_indices, 'Non EUR AGs + Real EUR', 'results/plots/noneur_bootstrap_combined.pdf')
# Out:
# Method: real_noneur
#   Full set Mean R²: 0.4849
#   Full set 95% CI: [0.4821, 0.4876]
#   Low-freq (<1%) Mean R²: 0.1064
#   Low-freq (<1%) 95% CI: [0.1006, 0.1123]
#   Rare (<0.1%) Mean R²: 0.0205
#   Rare (<0.1%) 95% CI: [0.0157, 0.0253]
# Method: pc_real_noneur
#   Full set Mean R²: 0.5626
#   Full set 95% CI: [0.5609, 0.5644]
#   Low-freq (<1%) Mean R²: 0.1584
#   Low-freq (<1%) 95% CI: [0.1557, 0.1612]
#   Rare (<0.1%) Mean R²: 0.0208
#   Rare (<0.1%) 95% CI: [0.0159, 0.0258]
# Method: pc_realeur_and_noneur_train_noneur
#   Full set Mean R²: 0.5702
#   Full set 95% CI: [0.5675, 0.5729]
#   Low-freq (<1%) Mean R²: 0.1735
#   Low-freq (<1%) 95% CI: [0.1687, 0.1782]
#   Rare (<0.1%) Mean R²: 0.0305
#   Rare (<0.1%) 95% CI: [0.0247, 0.0362]
# Method: hclt_noneur
#   Full set Mean R²: 0.5220
#   Full set 95% CI: [0.5202, 0.5238]
#   Low-freq (<1%) Mean R²: 0.0981
#   Low-freq (<1%) 95% CI: [0.0948, 0.1014]
#   Rare (<0.1%) Mean R²: 0.0042
#   Rare (<0.1%) 95% CI: [0.0021, 0.0063]
# Method: rbm_noneur
#   Full set Mean R²: 0.4760
#   Full set 95% CI: [0.4741, 0.4778]
#   Low-freq (<1%) Mean R²: 0.0423
#   Low-freq (<1%) 95% CI: [0.0391, 0.0455]
#   Rare (<0.1%) Mean R²: 0.0028
#   Rare (<0.1%) 95% CI: [0.0013, 0.0042]
# Method: wgan_noneur
#   Full set Mean R²: 0.4223
#   Full set 95% CI: [0.4209, 0.4237]
#   Low-freq (<1%) Mean R²: 0.0032
#   Low-freq (<1%) 95% CI: [0.0023, 0.0041]
#   Rare (<0.1%) Mean R²: 0.0004
#   Rare (<0.1%) 95% CI: [0.0001, 0.0006]
# Method: hclt_noneur_combined
#   Full set Mean R²: 0.5596
#   Full set 95% CI: [0.5567, 0.5625]
#   Low-freq (<1%) Mean R²: 0.1600
#   Low-freq (<1%) 95% CI: [0.1545, 0.1654]
#   Rare (<0.1%) Mean R²: 0.0255
#   Rare (<0.1%) 95% CI: [0.0212, 0.0298]
# Method: rbm_noneur_combined
#   Full set Mean R²: 0.5278
#   Full set 95% CI: [0.5242, 0.5315]
#   Low-freq (<1%) Mean R²: 0.1225
#   Low-freq (<1%) 95% CI: [0.1163, 0.1287]
#   Rare (<0.1%) Mean R²: 0.0243
#   Rare (<0.1%) 95% CI: [0.0191, 0.0294]
# Method: wgan_noneur_combined
#   Full set Mean R²: 0.5072
#   Full set 95% CI: [0.5040, 0.5104]
#   Low-freq (<1%) Mean R²: 0.1109
#   Low-freq (<1%) 95% CI: [0.1047, 0.1170]
#   Rare (<0.1%) Mean R²: 0.0206
#   Rare (<0.1%) 95% CI: [0.0158, 0.0253]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])
     
all_methods = [
    'real_afr', 'pc_real_afr', 'pc_realeur_and_afr_train_afr',
    'hclt_afr', 'rbm_afr', 'wgan_afr',
    'hclt_afr_combined', 'rbm_afr_combined', 'wgan_afr_combined' 
]
all_colors = ['black', 'dodgerblue', 'dodgerblue', 'b', 'orange', 'g', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', 's', '^', 'D', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', f'{my_method_name} (direct)',
    f'{my_method_name}', 'RBM', 'WGAN',
    f'{my_method_name}', 'RBM', 'WGAN', 
]
all_linestyles = ['--', '-', '-', '-', '-', '-', '-', '-', '-']

baseline_indices = [0, 1, 3, 4, 5]
combined_indices = [0, 2, 6, 7, 8]

# --- Function to summarize bootstrap stats ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load and filter data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/r2/{method}_afr.csv')
    df = df[df['MAF'] > 0].copy()  # remove MAF=0 variants
    r2_cols = [c for c in df.columns if c.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]

    print(f"Method: {method}")
    summarize_bootstrap(df, boot_cols, "Full set")
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

    method_data[method] = df

# --- Plotting function ---
def plot_methods(indices, title, filename):
    fig, ax = plt.subplots(figsize=(8,6))
    for idx in indices:
        method_name = all_methods[idx]
        df = method_data[method_name]
        boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
        bin_indices = np.digitize(df['MAF'], bins) - 1

        mean_r2, ci_low, ci_high = [], [], []

        for i in range(num_bins):
            in_bin = bin_indices == i
            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            mean = np.mean(bin_means)
            mean_r2.append(mean)
            ci_low.append(np.percentile(bin_means, 2.5))
            ci_high.append(np.percentile(bin_means, 97.5))

        ax.plot(bin_centers, mean_r2, marker=all_markers[idx], linestyle=all_linestyles[idx],
                color=all_colors[idx], label=all_labels[idx])
        ax.fill_between(bin_centers, ci_low, ci_high, color=all_colors[idx], alpha=0.2)

    ax.set_xscale('log')
    # ax.set_yscale('asinh', linear_width=0.1)
    ax.set_xticks([1e-4, 1e-3, 1e-2, 1e-1])
    ax.set_xticklabels([r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
    ax.set_yticks(np.linspace(0, 1, 6))
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax.set_ylabel(r'Average $r^2$', fontsize=18)
    ax.set_xlabel('MAF', fontsize=18)
    # ax.set_title(title, fontsize=18)
    ax.legend(fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, format="pdf", dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Generate plots ---
plot_methods(baseline_indices, 'AFR AGs', 'results/plots/afr_bootstrap_baseline.pdf')
plot_methods(combined_indices, 'AFR AGs + Real EUR', 'results/plots/afr_bootstrap_combined.pdf')
# Out:
# Method: real_afr
#   Full set Mean R²: 0.3678
#   Full set 95% CI: [0.3572, 0.3785]
#   Low-freq (<1%) Mean R²: 0.0188
#   Low-freq (<1%) 95% CI: [0.0125, 0.0252]
#   Rare (<0.1%) Mean R²: 0.0026
#   Rare (<0.1%) 95% CI: [0.0006, 0.0045]
# Method: pc_real_afr
#   Full set Mean R²: 0.4620
#   Full set 95% CI: [0.4557, 0.4682]
#   Low-freq (<1%) Mean R²: 0.0429
#   Low-freq (<1%) 95% CI: [0.0395, 0.0463]
#   Rare (<0.1%) Mean R²: 0.0064
#   Rare (<0.1%) 95% CI: [0.0048, 0.0079]
# Method: pc_realeur_and_afr_train_afr
#   Full set Mean R²: 0.4705
#   Full set 95% CI: [0.4607, 0.4802]
#   Low-freq (<1%) Mean R²: 0.0526
#   Low-freq (<1%) 95% CI: [0.0464, 0.0587]
#   Rare (<0.1%) Mean R²: 0.0071
#   Rare (<0.1%) 95% CI: [0.0049, 0.0093]
# Method: hclt_afr
#   Full set Mean R²: 0.4421
#   Full set 95% CI: [0.4379, 0.4463]
#   Low-freq (<1%) Mean R²: 0.0268
#   Low-freq (<1%) 95% CI: [0.0252, 0.0284]
#   Rare (<0.1%) Mean R²: 0.0009
#   Rare (<0.1%) 95% CI: [0.0006, 0.0013]
# Method: rbm_afr
#   Full set Mean R²: 0.4288
#   Full set 95% CI: [0.4238, 0.4338]
#   Low-freq (<1%) Mean R²: 0.0275
#   Low-freq (<1%) 95% CI: [0.0246, 0.0303]
#   Rare (<0.1%) Mean R²: 0.0019
#   Rare (<0.1%) 95% CI: [0.0005, 0.0034]
# Method: wgan_afr
#   Full set Mean R²: 0.3807
#   Full set 95% CI: [0.3791, 0.3822]
#   Low-freq (<1%) Mean R²: 0.0086
#   Low-freq (<1%) 95% CI: [0.0079, 0.0092]
#   Rare (<0.1%) Mean R²: 0.0003
#   Rare (<0.1%) 95% CI: [0.0000, 0.0005]
# Method: hclt_afr_combined
#   Full set Mean R²: 0.4638
#   Full set 95% CI: [0.4540, 0.4735]
#   Low-freq (<1%) Mean R²: 0.0434
#   Low-freq (<1%) 95% CI: [0.0369, 0.0500]
#   Rare (<0.1%) Mean R²: 0.0035
#   Rare (<0.1%) 95% CI: [0.0017, 0.0054]
# Method: rbm_afr_combined
#   Full set Mean R²: 0.4458
#   Full set 95% CI: [0.4351, 0.4564]
#   Low-freq (<1%) Mean R²: 0.0399
#   Low-freq (<1%) 95% CI: [0.0331, 0.0467]
#   Rare (<0.1%) Mean R²: 0.0039
#   Rare (<0.1%) 95% CI: [0.0019, 0.0059]
# Method: wgan_afr_combined
#   Full set Mean R²: 0.4234
#   Full set 95% CI: [0.4123, 0.4346]
#   Low-freq (<1%) Mean R²: 0.0284
#   Low-freq (<1%) 95% CI: [0.0219, 0.0349]
#   Rare (<0.1%) Mean R²: 0.0027
#   Rare (<0.1%) 95% CI: [0.0008, 0.0045]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])  # For plotting

all_methods = [
    'UKBB_real_8020', 'UKBB_pc_real_8020', 
    'UKBB_hclt_8020', 'UKBB_rbm_8020', 'UKBB_wgan_8020'
]
all_colors = ['black', 'dodgerblue', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', 
    f'{my_method_name}', 'RBM', 'WGAN' 
]
all_linestyles = ['--', '-', '-', '-', '-']

# --- Function to summarize bootstrap statistics ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load and filter data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/r2/{method}_bootstraps.csv')
    
    # Remove MAF=0 variants
    df = df[df['MAF'] > 0].copy()

    r2_cols = [col for col in df.columns if col.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)
    
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
    
    print(f"Method: {method}")
    summarize_bootstrap(df, boot_cols, "Full set")
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")
    
    method_data[method] = df

# --- Plot each method with CI bands ---
plt.figure(figsize=(8,6))

for method_name, color, marker, label, linestyle in zip(
    all_methods, all_colors, all_markers, all_labels, all_linestyles
):
    df = method_data[method_name]
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
    bin_indices = np.digitize(df['MAF'], bins) - 1

    mean_r2 = []
    ci_low = []
    ci_high = []

    for i in range(num_bins):
        in_bin = bin_indices == i
        if not np.any(in_bin):
            mean_r2.append(np.nan)
            ci_low.append(np.nan)
            ci_high.append(np.nan)
            continue

        boot_values = df.loc[in_bin, boot_cols].values
        bin_means = np.nanmean(boot_values, axis=0)
        mean = np.mean(bin_means)

        mean_r2.append(mean)
        ci_low.append(np.percentile(bin_means, 2.5))
        ci_high.append(np.percentile(bin_means, 97.5))

    plt.plot(bin_centers, mean_r2, marker=marker, linestyle=linestyle, color=color, label=label)
    plt.fill_between(bin_centers, ci_low, ci_high, color=color, alpha=0.2)

# --- Formatting ---
plt.xscale('log')
plt.xticks([1e-4, 1e-3, 1e-2, 1e-1], [r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('MAF', fontsize=18)
plt.ylabel(r'Average $r^2$', fontsize=18)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=14)
plt.tight_layout()
plt.savefig("results/plots/UKBB_8020_bootstrap_ci.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Method: UKBB_real_8020
#   Full set Mean R²: 0.9568
#   Full set 95% CI: [0.9535, 0.9601]
#   Low-freq (<1%) Mean R²: 0.9144
#   Low-freq (<1%) 95% CI: [0.9072, 0.9217]
#   Rare (<0.1%) Mean R²: 0.8178
#   Rare (<0.1%) 95% CI: [0.7962, 0.8394]
# Method: UKBB_pc_real_8020
#   Full set Mean R²: 0.9063
#   Full set 95% CI: [0.9033, 0.9093]
#   Low-freq (<1%) Mean R²: 0.8283
#   Low-freq (<1%) 95% CI: [0.8218, 0.8347]
#   Rare (<0.1%) Mean R²: 0.7085
#   Rare (<0.1%) 95% CI: [0.6873, 0.7297]
# Method: UKBB_hclt_8020
#   Full set Mean R²: 0.7499
#   Full set 95% CI: [0.7484, 0.7514]
#   Low-freq (<1%) Mean R²: 0.5250
#   Low-freq (<1%) 95% CI: [0.5220, 0.5280]
#   Rare (<0.1%) Mean R²: 0.2627
#   Rare (<0.1%) 95% CI: [0.2520, 0.2735]
# Method: UKBB_rbm_8020
#   Full set Mean R²: 0.6685
#   Full set 95% CI: [0.6668, 0.6703]
#   Low-freq (<1%) Mean R²: 0.3806
#   Low-freq (<1%) 95% CI: [0.3769, 0.3842]
#   Rare (<0.1%) Mean R²: 0.1176
#   Rare (<0.1%) 95% CI: [0.1117, 0.1234]
# Method: UKBB_wgan_8020
#   Full set Mean R²: 0.5231
#   Full set 95% CI: [0.5224, 0.5238]
#   Low-freq (<1%) Mean R²: 0.0869
#   Low-freq (<1%) 95% CI: [0.0862, 0.0876]
#   Rare (<0.1%) Mean R²: 0.0002
#   Rare (<0.1%) 95% CI: [0.0001, 0.0003]

# %%
# --- Slides: UKBB 8020 bar plot (RBM, WGAN, GPC, GPC direct) ---

ukbb_slides_methods = ['UKBB_rbm_8020', 'UKBB_wgan_8020', 'UKBB_pc_real_8020']
ukbb_slides_colors  = ['orange', 'green', 'blue']
ukbb_slides_labels  = ['RBM', 'WGAN', 'GPC']

ukbb_bar_categories = ['Rare', 'Low-freq', 'All']
ukbb_maf_filters = [
    lambda df: df['MAF'] < 0.001,
    lambda df: df['MAF'] < 0.01,
    lambda df: df['MAF'] > 0,
]

n_cats_uk    = len(ukbb_bar_categories)
n_methods_uk = len(ukbb_slides_methods)
bar_width_uk = 0.18
x_uk = np.arange(n_cats_uk)

fig_uk, ax_uk = plt.subplots(figsize=(9, 6))

for ji, (method, color, label) in enumerate(zip(ukbb_slides_methods, ukbb_slides_colors, ukbb_slides_labels)):
    df = method_data[method]
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
    means_uk, sems_uk = [], []
    for filt in ukbb_maf_filters:
        subset = df[filt(df)]
        if subset.empty:
            means_uk.append(0); sems_uk.append(0); continue
        boot_means = subset[boot_cols].mean(skipna=True)
        means_uk.append(boot_means.mean())
        sems_uk.append(boot_means.std(ddof=1))
    offset = (ji - (n_methods_uk - 1) / 2) * bar_width_uk
    ax_uk.bar(x_uk + offset, means_uk, bar_width_uk, color=color, label=label,
              yerr=sems_uk, capsize=4, error_kw=dict(linewidth=1.5))
    for xi, (mean, sem) in enumerate(zip(means_uk, sems_uk)):
        ax_uk.text(xi + offset, mean + sem + 0.012, f'{mean:.2f}',
                   ha='center', va='bottom', fontsize=9, color='#333333')

ax_uk.set_xlabel("SNP frequency", fontsize=18)
ax_uk.set_xticks(x_uk)
ax_uk.set_xticklabels(ukbb_bar_categories, fontsize=16)
ax_uk.tick_params(axis='y', labelsize=15)
ax_uk.set_ylabel(r'Average $r^2$', fontsize=18)
ax_uk.set_ylim(0, None)
ax_uk.legend(fontsize=15, frameon=False)
ax_uk.spines['top'].set_visible(False)
ax_uk.spines['right'].set_visible(False)
ax_uk.yaxis.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
ax_uk.set_axisbelow(True)

plt.tight_layout()
plt.savefig('results/plots/UKBB_8020_bootstrap_ci_slides.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- Chromosomes ---
chroms = [2, 11, 12, 14, 18]
chroms_box_only = [22]

# --- Methods ---
methods = ['real', 'pc', 'hclt', 'rbm']

method_labels = {
    'real': 'Impute5',
    'pc': f'{my_method_name} (direct)',
    'hclt': f'{my_method_name}',
    'rbm': 'RBM'
}

method_colors = {
    'real': 'black',
    'pc': 'dodgerblue',
    'hclt': 'blue',
    'rbm': 'orange'
}

method_markers = {
    'real': 'o',
    'pc': 's',
    'hclt': 's',
    'rbm': '^'
}

method_linestyles = {
    'real': '--',
    'pc': '-',
    'hclt': '-',
    'rbm': '-'
}

# --- MAF bins (for line plots) ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])

# --- Box plot bin definitions ---
box_bin_labels = ['Rare\n(MAF < 0.1%)', 'Low-freq\n(MAF < 1%)', 'All']
box_bin_filters = [
    lambda maf: maf < 0.001,                       # Rare
    lambda maf: maf < 0.01,                         # Low-freq
    lambda maf: np.ones(len(maf), dtype=bool),      # All
]
num_box_bins = len(box_bin_labels)

def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Storage for aggregated box plot data ---
# all_means[method][box_bin_index] = list of per-chromosome mean r2 values
all_means = {method: [[] for _ in range(num_box_bins)] for method in methods}

# --- Panel plot setup ---
fig, axes = plt.subplots(2, 3, figsize=(14, 8))
axes = axes.flatten()

for i, chrnum in enumerate(chroms):

    ax = axes[i]
    print(f"\nProcessing chr{chrnum}")

    for method in methods:

        filename = f"results/r2/UKBB_{method}_chr{chrnum}_8020_bootstraps.csv"

        if not os.path.exists(filename):
            print(f"Skipping missing file: {filename}")
            continue

        df = pd.read_csv(filename)
        df = df[df['MAF'] > 0].copy()

        r2_cols = [c for c in df.columns if c.startswith("R2")]
        df[r2_cols] = df[r2_cols].fillna(0)

        boot_cols = [c for c in df.columns if c.startswith("R2_boot_")]

        print(f"  Method: {method_labels[method]}")
        summarize_bootstrap(df, boot_cols, "Full set")
        summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
        summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

        bin_indices = np.digitize(df['MAF'], bins) - 1

        mean_r2 = []
        ci_low = []
        ci_high = []

        for b in range(num_bins):

            in_bin = bin_indices == b

            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue

            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)

            mean = np.mean(bin_means)

            mean_r2.append(mean)
            ci_low.append(np.percentile(bin_means, 2.5))
            ci_high.append(np.percentile(bin_means, 97.5))

        ax.plot(
            bin_centers,
            mean_r2,
            marker=method_markers[method],
            linestyle=method_linestyles[method],
            color=method_colors[method],
            label=method_labels[method]
        )

        ax.fill_between(
            bin_centers,
            ci_low,
            ci_high,
            color=method_colors[method],
            alpha=0.2
        )

        # --- Accumulate box plot data using the 3 new bins ---
        for b, filt in enumerate(box_bin_filters):
            in_bin = filt(df['MAF'].values)
            if not np.any(in_bin):
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            all_means[method][b].append(np.mean(bin_means))

    ax.set_xscale('log')
    ax.set_title(f"chr{chrnum}", fontsize=14)
    ax.set_xticks(
        [1e-4, 1e-3, 1e-2, 1e-1],
        [r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"]
    )
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)

axes[0].set_ylabel(r'Average $r^2$', fontsize=14)
axes[3].set_ylabel(r'Average $r^2$', fontsize=14)

for ax in axes[3:5]:
    ax.set_xlabel("MAF", fontsize=14)

axes[5].axis("off")
handles, labels = axes[0].get_legend_handles_labels()
axes[5].legend(handles, labels, loc="center", frameon=False, fontsize=14)

plt.tight_layout()
plt.savefig(
    "results/plots/UKBB_8020_bootstrap_ci_panel.pdf",
    dpi=300,
    bbox_inches='tight'
)
plt.show()

# --- Accumulate box-plot-only chromosomes ---
for chrnum in chroms_box_only:
    print(f"\nProcessing chr{chrnum} (box plot only)")
    for method in methods:
        filename = f"results/r2/UKBB_{method}_chr{chrnum}_8020_bootstraps.csv"
        if not os.path.exists(filename):
            print(f"Skipping missing file: {filename}")
            continue

        df = pd.read_csv(filename)
        df = df[df['MAF'] > 0].copy()

        r2_cols = [c for c in df.columns if c.startswith("R2")]
        df[r2_cols] = df[r2_cols].fillna(0)
        boot_cols = [c for c in df.columns if c.startswith("R2_boot_")]

        print(f"  Method: {method_labels[method]}")
        summarize_bootstrap(df, boot_cols, "Full set")
        summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
        summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

        for b, filt in enumerate(box_bin_filters):
            in_bin = filt(df['MAF'].values)
            if not np.any(in_bin):
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            all_means[method][b].append(np.mean(bin_means))
            
# --- Grouped box plot aggregated across chromosomes ---
fig2, ax2 = plt.subplots(figsize=(8, 5))

n_methods = len(methods)
width = 0.15
x_base = np.arange(num_box_bins)
offsets = np.linspace(
    -(n_methods - 1) / 2 * width,
     (n_methods - 1) / 2 * width,
    n_methods
)

for j, method in enumerate(methods):

    positions = x_base + offsets[j]
    data = [
        [v for v in all_means[method][b] if not np.isnan(v)]
        for b in range(num_box_bins)
    ]

    bp = ax2.boxplot(
        data,
        positions=positions,
        widths=width * 0.8,
        patch_artist=True,
        manage_ticks=False,
        medianprops=dict(color='white', linewidth=1.5),
        whiskerprops=dict(color=method_colors[method], linewidth=1.2),
        capprops=dict(color=method_colors[method], linewidth=1.2),
        flierprops=dict(
            marker=method_markers[method],
            color=method_colors[method],
            markersize=5,
            linestyle='none'
        ),
        boxprops=dict(
            facecolor=method_colors[method],
            color=method_colors[method],
            alpha=0.7,
            linewidth=1.2
        ),
    )

    # Add scatter points (one per chromosome) on top
    for b, vals in enumerate(data):
        ax2.scatter(
            np.full(len(vals), positions[b]),
            vals,
            color=method_colors[method],
            marker=method_markers[method],
            s=30,
            zorder=5,
            alpha=0.9
        )

    # Invisible line for legend
    ax2.plot(
        [], [],
        color=method_colors[method],
        linestyle=method_linestyles[method],
        marker=method_markers[method],
        label=method_labels[method]
    )

ax2.set_xticks(x_base)
ax2.set_xticklabels(box_bin_labels, fontsize=12)
ax2.set_xlabel("MAF bin", fontsize=14)
ax2.set_ylabel(r'Average $r^2$', fontsize=14)
ax2.grid(True, axis='y', linestyle='--', linewidth=0.5)
ax2.legend(frameon=False, fontsize=12)

plt.tight_layout()
plt.savefig(
    "results/plots/UKBB_8020_bootstrap_boxplot_aggregated.pdf",
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# Out:
# Processing chr2
#   Method: Impute5
#   Full set Mean R²: 0.9487
#   Full set 95% CI: [0.9453, 0.9521]
#   Low-freq (<1%) Mean R²: 0.8939
#   Low-freq (<1%) 95% CI: [0.8861, 0.9018]
#   Rare (<0.1%) Mean R²: 0.8046
#   Rare (<0.1%) 95% CI: [0.7821, 0.8272]
#   Method: GPC (direct)
#   Full set Mean R²: 0.8844
#   Full set 95% CI: [0.8818, 0.8870]
#   Low-freq (<1%) Mean R²: 0.7740
#   Low-freq (<1%) 95% CI: [0.7677, 0.7804]
#   Rare (<0.1%) Mean R²: 0.6538
#   Rare (<0.1%) 95% CI: [0.6345, 0.6732]
#   Method: GPC
#   Full set Mean R²: 0.7462
#   Full set 95% CI: [0.7440, 0.7484]
#   Low-freq (<1%) Mean R²: 0.4911
#   Low-freq (<1%) 95% CI: [0.4859, 0.4962]
#   Rare (<0.1%) Mean R²: 0.2694
#   Rare (<0.1%) 95% CI: [0.2529, 0.2860]
#   Method: RBM
#   Full set Mean R²: 0.6047
#   Full set 95% CI: [0.6032, 0.6063]
#   Low-freq (<1%) Mean R²: 0.2219
#   Low-freq (<1%) 95% CI: [0.2185, 0.2253]
#   Rare (<0.1%) Mean R²: 0.0427
#   Rare (<0.1%) 95% CI: [0.0373, 0.0481]
#
# Processing chr11
#   Method: Impute5
#   Full set Mean R²: 0.9587
#   Full set 95% CI: [0.9558, 0.9616]
#   Low-freq (<1%) Mean R²: 0.9034
#   Low-freq (<1%) 95% CI: [0.8961, 0.9107]
#   Rare (<0.1%) Mean R²: 0.8009
#   Rare (<0.1%) 95% CI: [0.7778, 0.8241]
#   Method: GPC (direct)
#   Full set Mean R²: 0.8949
#   Full set 95% CI: [0.8913, 0.8984]
#   Low-freq (<1%) Mean R²: 0.7690
#   Low-freq (<1%) 95% CI: [0.7598, 0.7781]
#   Rare (<0.1%) Mean R²: 0.6207
#   Rare (<0.1%) 95% CI: [0.5976, 0.6438]
#   Method: GPC
#   Full set Mean R²: 0.7703
#   Full set 95% CI: [0.7682, 0.7723]
#   Low-freq (<1%) Mean R²: 0.4839
#   Low-freq (<1%) 95% CI: [0.4784, 0.4895]
#   Rare (<0.1%) Mean R²: 0.2717
#   Rare (<0.1%) 95% CI: [0.2568, 0.2866]
#   Method: RBM
#   Full set Mean R²: 0.6402
#   Full set 95% CI: [0.6387, 0.6417]
#   Low-freq (<1%) Mean R²: 0.2141
#   Low-freq (<1%) 95% CI: [0.2106, 0.2175]
#   Rare (<0.1%) Mean R²: 0.0325
#   Rare (<0.1%) 95% CI: [0.0299, 0.0352]
#
# Processing chr12
#   Method: Impute5
#   Full set Mean R²: 0.9704
#   Full set 95% CI: [0.9682, 0.9726]
#   Low-freq (<1%) Mean R²: 0.9368
#   Low-freq (<1%) 95% CI: [0.9316, 0.9420]
#   Rare (<0.1%) Mean R²: 0.8226
#   Rare (<0.1%) 95% CI: [0.7947, 0.8506]
#   Method: GPC (direct)
#   Full set Mean R²: 0.9339
#   Full set 95% CI: [0.9313, 0.9365]
#   Low-freq (<1%) Mean R²: 0.8691
#   Low-freq (<1%) 95% CI: [0.8627, 0.8755]
#   Rare (<0.1%) Mean R²: 0.7227
#   Rare (<0.1%) 95% CI: [0.6955, 0.7499]
#   Method: GPC
#   Full set Mean R²: 0.8227
#   Full set 95% CI: [0.8209, 0.8244]
#   Low-freq (<1%) Mean R²: 0.6355
#   Low-freq (<1%) 95% CI: [0.6319, 0.6392]
#   Rare (<0.1%) Mean R²: 0.3304
#   Rare (<0.1%) 95% CI: [0.3135, 0.3474]
#   Method: RBM
#   Full set Mean R²: 0.7167
#   Full set 95% CI: [0.7152, 0.7182]
#   Low-freq (<1%) Mean R²: 0.4225
#   Low-freq (<1%) 95% CI: [0.4188, 0.4263]
#   Rare (<0.1%) Mean R²: 0.1153
#   Rare (<0.1%) 95% CI: [0.1050, 0.1257]
#
# Processing chr14
#   Method: Impute5
#   Full set Mean R²: 0.9455
#   Full set 95% CI: [0.9427, 0.9483]
#   Low-freq (<1%) Mean R²: 0.8969
#   Low-freq (<1%) 95% CI: [0.8912, 0.9026]
#   Rare (<0.1%) Mean R²: 0.7897
#   Rare (<0.1%) 95% CI: [0.7653, 0.8140]
#   Method: GPC (direct)
#   Full set Mean R²: 0.8777
#   Full set 95% CI: [0.8743, 0.8810]
#   Low-freq (<1%) Mean R²: 0.7809
#   Low-freq (<1%) 95% CI: [0.7741, 0.7878]
#   Rare (<0.1%) Mean R²: 0.6268
#   Rare (<0.1%) 95% CI: [0.6029, 0.6506]
#   Method: GPC
#   Full set Mean R²: 0.7610
#   Full set 95% CI: [0.7590, 0.7631]
#   Low-freq (<1%) Mean R²: 0.5612
#   Low-freq (<1%) 95% CI: [0.5569, 0.5655]
#   Rare (<0.1%) Mean R²: 0.2932
#   Rare (<0.1%) 95% CI: [0.2781, 0.3084]
#   Method: RBM
#   Full set Mean R²: 0.5688
#   Full set 95% CI: [0.5670, 0.5705]
#   Low-freq (<1%) Mean R²: 0.2431
#   Low-freq (<1%) 95% CI: [0.2397, 0.2465]
#   Rare (<0.1%) Mean R²: 0.0526
#   Rare (<0.1%) 95% CI: [0.0474, 0.0579]
#
# Processing chr18
#   Method: Impute5
#   Full set Mean R²: 0.9498
#   Full set 95% CI: [0.9465, 0.9531]
#   Low-freq (<1%) Mean R²: 0.8968
#   Low-freq (<1%) 95% CI: [0.8895, 0.9041]
#   Rare (<0.1%) Mean R²: 0.7860
#   Rare (<0.1%) 95% CI: [0.7589, 0.8130]
#   Method: GPC (direct)
#   Full set Mean R²: 0.8864
#   Full set 95% CI: [0.8834, 0.8895]
#   Low-freq (<1%) Mean R²: 0.7794
#   Low-freq (<1%) 95% CI: [0.7725, 0.7863]
#   Rare (<0.1%) Mean R²: 0.6309
#   Rare (<0.1%) 95% CI: [0.6046, 0.6573]
#   Method: GPC
#   Full set Mean R²: 0.7594
#   Full set 95% CI: [0.7572, 0.7615]
#   Low-freq (<1%) Mean R²: 0.5225
#   Low-freq (<1%) 95% CI: [0.5174, 0.5275]
#   Rare (<0.1%) Mean R²: 0.2926
#   Rare (<0.1%) 95% CI: [0.2755, 0.3097]
#   Method: RBM
#   Full set Mean R²: 0.5977
#   Full set 95% CI: [0.5962, 0.5993]
#   Low-freq (<1%) Mean R²: 0.2216
#   Low-freq (<1%) 95% CI: [0.2184, 0.2248]
#   Rare (<0.1%) Mean R²: 0.0366
#   Rare (<0.1%) 95% CI: [0.0293, 0.0439]
# Processing chr22 (box plot only)
#   Method: Impute5
#   Full set Mean R²: 0.9568
#   Full set 95% CI: [0.9535, 0.9601]
#   Low-freq (<1%) Mean R²: 0.9144
#   Low-freq (<1%) 95% CI: [0.9072, 0.9217]
#   Rare (<0.1%) Mean R²: 0.8178
#   Rare (<0.1%) 95% CI: [0.7962, 0.8394]
#   Method: GPC (direct)
#   Full set Mean R²: 0.9063
#   Full set 95% CI: [0.9033, 0.9093]
#   Low-freq (<1%) Mean R²: 0.8283
#   Low-freq (<1%) 95% CI: [0.8218, 0.8347]
#   Rare (<0.1%) Mean R²: 0.7085
#   Rare (<0.1%) 95% CI: [0.6873, 0.7297]
#   Method: GPC
#   Full set Mean R²: 0.7499
#   Full set 95% CI: [0.7484, 0.7514]
#   Low-freq (<1%) Mean R²: 0.5250
#   Low-freq (<1%) 95% CI: [0.5220, 0.5280]
#   Rare (<0.1%) Mean R²: 0.2627
#   Rare (<0.1%) 95% CI: [0.2520, 0.2735]
#   Method: RBM
#   Full set Mean R²: 0.6685
#   Full set 95% CI: [0.6668, 0.6703]
#   Low-freq (<1%) Mean R²: 0.3806
#   Low-freq (<1%) 95% CI: [0.3769, 0.3842]
#   Rare (<0.1%) Mean R²: 0.1176
#   Rare (<0.1%) 95% CI: [0.1117, 0.1234]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])

all_methods = [
    'UKBB_real_noneur', 'UKBB_pc_real_noneur', 'UKBB_pc_realeur_and_noneur_train',
    'UKBB_hclt_noneur', 'UKBB_rbm_noneur', 'UKBB_wgan_noneur', 
    'UKBB_hclt_noneur_combined', 'UKBB_rbm_noneur_combined', 'UKBB_wgan_noneur_combined', 
]
all_colors = ['black', 'dodgerblue', 'dodgerblue', 'b', 'orange', 'g', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', 's', '^', 'D', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', f'{my_method_name} (direct)',
    f'{my_method_name}', 'RBM', 'WGAN',
    f'{my_method_name}', 'RBM', 'WGAN', 
]
all_linestyles = ['--', '-', '-', '-', '-', '-', '-', '-', '-']

baseline_indices = [0, 1, 3, 4, 5]
combined_indices = [0, 2, 6, 7, 8]

# --- Function to summarize bootstrap stats ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load and filter data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/r2/{method}_bootstraps.csv')
    df = df[df['MAF'] > 0].copy()  # remove MAF=0 variants
    r2_cols = [c for c in df.columns if c.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]

    print(f"Method: {method}")
    summarize_bootstrap(df, boot_cols, "Full set")
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

    method_data[method] = df

# --- Plotting function ---
def plot_methods(indices, title, filename):
    fig, ax = plt.subplots(figsize=(8,6))
    for idx in indices:
        method_name = all_methods[idx]
        df = method_data[method_name]
        boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
        bin_indices = np.digitize(df['MAF'], bins) - 1

        mean_r2, ci_low, ci_high = [], [], []

        for i in range(num_bins):
            in_bin = bin_indices == i
            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            mean = np.mean(bin_means)
            mean_r2.append(mean)
            ci_low.append(np.percentile(bin_means, 2.5))
            ci_high.append(np.percentile(bin_means, 97.5))

        ax.plot(bin_centers, mean_r2, marker=all_markers[idx], linestyle=all_linestyles[idx],
                color=all_colors[idx], label=all_labels[idx])
        ax.fill_between(bin_centers, ci_low, ci_high, color=all_colors[idx], alpha=0.2)

    ax.set_xscale('log')
    ax.set_xticks([1e-4, 1e-3, 1e-2, 1e-1])
    ax.set_xticklabels([r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
    ax.set_yticks(np.linspace(0, 1, 6))
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax.set_ylabel(r'Average $r^2$', fontsize=18)
    ax.set_xlabel('MAF', fontsize=18)
    # ax.set_title(title, fontsize=18)
    ax.legend(fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, format="pdf", dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Generate plots ---
plot_methods(baseline_indices, 'Non EUR AGs', 'results/plots/UKBB_noneur_bootstrap_baseline.pdf')
plot_methods(combined_indices, 'Non EUR AGs + Real EUR', 'results/plots/UKBB_noneur_bootstrap_combined.pdf')
# Out:
# Method: UKBB_real_noneur
#   Full set Mean R²: 0.7334
#   Full set 95% CI: [0.7252, 0.7415]
#   Low-freq (<1%) Mean R²: 0.5062
#   Low-freq (<1%) 95% CI: [0.4908, 0.5217]
#   Rare (<0.1%) Mean R²: 0.2110
#   Rare (<0.1%) 95% CI: [0.1737, 0.2483]
# Method: UKBB_pc_real_noneur
#   Full set Mean R²: 0.7494
#   Full set 95% CI: [0.7422, 0.7566]
#   Low-freq (<1%) Mean R²: 0.4977
#   Low-freq (<1%) 95% CI: [0.4827, 0.5128]
#   Rare (<0.1%) Mean R²: 0.1587
#   Rare (<0.1%) 95% CI: [0.1274, 0.1899]
# Method: UKBB_pc_realeur_and_noneur_train
#   Full set Mean R²: 0.7591
#   Full set 95% CI: [0.7517, 0.7665]
#   Low-freq (<1%) Mean R²: 0.5219
#   Low-freq (<1%) 95% CI: [0.5067, 0.5371]
#   Rare (<0.1%) Mean R²: 0.2103
#   Rare (<0.1%) 95% CI: [0.1747, 0.2459]
# Method: UKBB_hclt_noneur
#   Full set Mean R²: 0.6558
#   Full set 95% CI: [0.6507, 0.6610]
#   Low-freq (<1%) Mean R²: 0.3331
#   Low-freq (<1%) 95% CI: [0.3229, 0.3432]
#   Rare (<0.1%) Mean R²: 0.0535
#   Rare (<0.1%) 95% CI: [0.0339, 0.0730]
# Method: UKBB_rbm_noneur
#   Full set Mean R²: 0.4950
#   Full set 95% CI: [0.4926, 0.4974]
#   Low-freq (<1%) Mean R²: 0.1277
#   Low-freq (<1%) 95% CI: [0.1232, 0.1322]
#   Rare (<0.1%) Mean R²: 0.0041
#   Rare (<0.1%) 95% CI: [0.0025, 0.0058]
# Method: UKBB_wgan_noneur
#   Full set Mean R²: 0.4614
#   Full set 95% CI: [0.4598, 0.4629]
#   Low-freq (<1%) Mean R²: 0.0594
#   Low-freq (<1%) 95% CI: [0.0582, 0.0605]
#   Rare (<0.1%) Mean R²: 0.0001
#   Rare (<0.1%) 95% CI: [-0.0001, 0.0004]
# Method: UKBB_hclt_noneur_combined
#   Full set Mean R²: 0.7628
#   Full set 95% CI: [0.7551, 0.7706]
#   Low-freq (<1%) Mean R²: 0.5303
#   Low-freq (<1%) 95% CI: [0.5149, 0.5456]
#   Rare (<0.1%) Mean R²: 0.2174
#   Rare (<0.1%) 95% CI: [0.1799, 0.2548]
# Method: UKBB_rbm_noneur_combined
#   Full set Mean R²: 0.7317
#   Full set 95% CI: [0.7233, 0.7401]
#   Low-freq (<1%) Mean R²: 0.4979
#   Low-freq (<1%) 95% CI: [0.4815, 0.5142]
#   Rare (<0.1%) Mean R²: 0.2097
#   Rare (<0.1%) 95% CI: [0.1714, 0.2481]
# Method: UKBB_wgan_noneur_combined
#   Full set Mean R²: 0.7393
#   Full set 95% CI: [0.7310, 0.7476]
#   Low-freq (<1%) Mean R²: 0.5099
#   Low-freq (<1%) 95% CI: [0.4943, 0.5255]
#   Rare (<0.1%) Mean R²: 0.2091
#   Rare (<0.1%) 95% CI: [0.1727, 0.2454]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9
bins = np.logspace(-4, np.log10(0.5), num_bins + 1)
bin_centers = np.sqrt(bins[:-1] * bins[1:])

all_methods = [
    'UKBB_real_afr', 'UKBB_pc_real_afr', 'UKBB_pc_realeur_and_afr_train',
    'UKBB_hclt_afr', 'UKBB_rbm_afr', 'UKBB_wgan_afr',
    'UKBB_hclt_afr_combined', 'UKBB_rbm_afr_combined', 'UKBB_wgan_afr_combined'
]
all_colors = ['black', 'dodgerblue', 'dodgerblue', 'b', 'orange', 'g', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', 's', '^', 'D', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', f'{my_method_name} (direct)',
    f'{my_method_name}', 'RBM', 'WGAN',
    f'{my_method_name}', 'RBM', 'WGAN', 
]
all_linestyles = ['--', '-', '-', '-', '-', '-', '-', '-', '-']

baseline_indices = [0, 1, 3, 4, 5]
combined_indices = [0, 2, 6, 7, 8]

# --- Function to summarize bootstrap stats ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = overall_mean - 1.96 * sem
    ci_upper = overall_mean + 1.96 * sem
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load and filter data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/r2/{method}_bootstraps.csv')
    df = df[df['MAF'] > 0].copy()  # remove MAF=0 variants
    r2_cols = [c for c in df.columns if c.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]

    print(f"Method: {method}")
    summarize_bootstrap(df, boot_cols, "Full set")
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

    method_data[method] = df

# --- Plotting function ---
def plot_methods(indices, title, filename):
    fig, ax = plt.subplots(figsize=(8,6))
    for idx in indices:
        method_name = all_methods[idx]
        df = method_data[method_name]
        boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
        bin_indices = np.digitize(df['MAF'], bins) - 1

        mean_r2, ci_low, ci_high = [], [], []

        for i in range(num_bins):
            in_bin = bin_indices == i
            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            mean = np.mean(bin_means)
            mean_r2.append(mean)
            ci_low.append(np.percentile(bin_means, 2.5))
            ci_high.append(np.percentile(bin_means, 97.5))

        ax.plot(bin_centers, mean_r2, marker=all_markers[idx], linestyle=all_linestyles[idx],
                color=all_colors[idx], label=all_labels[idx])
        ax.fill_between(bin_centers, ci_low, ci_high, color=all_colors[idx], alpha=0.2)

    ax.set_xscale('log')
    ax.set_xticks([1e-4, 1e-3, 1e-2, 1e-1])
    ax.set_xticklabels([r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
    ax.set_yticks(np.linspace(0, 1, 6))
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax.set_ylabel(r'Average $r^2$', fontsize=18)
    ax.set_xlabel('MAF', fontsize=18)
    # ax.set_title(title, fontsize=18)
    ax.legend(fontsize=14)
    plt.tight_layout()
    plt.savefig(filename, format="pdf", dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Generate plots ---
plot_methods(baseline_indices, 'AFR AGs', 'results/plots/UKBB_afr_bootstrap_baseline.pdf')
plot_methods(combined_indices, 'AFR AGs + Real EUR', 'results/plots/UKBB_afr_bootstrap_combined.pdf')
# Out:
# Method: UKBB_real_afr
#   Full set Mean R²: 0.6450
#   Full set 95% CI: [0.6270, 0.6630]
#   Low-freq (<1%) Mean R²: 0.3840
#   Low-freq (<1%) 95% CI: [0.3539, 0.4140]
#   Rare (<0.1%) Mean R²: 0.1150
#   Rare (<0.1%) 95% CI: [0.0913, 0.1387]
# Method: UKBB_pc_real_afr
#   Full set Mean R²: 0.6786
#   Full set 95% CI: [0.6628, 0.6944]
#   Low-freq (<1%) Mean R²: 0.3636
#   Low-freq (<1%) 95% CI: [0.3374, 0.3899]
#   Rare (<0.1%) Mean R²: 0.0642
#   Rare (<0.1%) 95% CI: [0.0507, 0.0777]
# Method: UKBB_pc_realeur_and_afr_train
#   Full set Mean R²: 0.6975
#   Full set 95% CI: [0.6794, 0.7155]
#   Low-freq (<1%) Mean R²: 0.4036
#   Low-freq (<1%) 95% CI: [0.3730, 0.4342]
#   Rare (<0.1%) Mean R²: 0.1107
#   Rare (<0.1%) 95% CI: [0.0867, 0.1348]
# Method: UKBB_hclt_afr
#   Full set Mean R²: 0.5821
#   Full set 95% CI: [0.5709, 0.5933]
#   Low-freq (<1%) Mean R²: 0.2070
#   Low-freq (<1%) 95% CI: [0.1905, 0.2235]
#   Rare (<0.1%) Mean R²: 0.0152
#   Rare (<0.1%) 95% CI: [0.0080, 0.0225]
# Method: UKBB_rbm_afr
#   Full set Mean R²: 0.4369
#   Full set 95% CI: [0.4277, 0.4461]
#   Low-freq (<1%) Mean R²: 0.0608
#   Low-freq (<1%) 95% CI: [0.0518, 0.0698]
#   Rare (<0.1%) Mean R²: 0.0007
#   Rare (<0.1%) 95% CI: [0.0002, 0.0011]
# Method: UKBB_wgan_afr
#   Full set Mean R²: 0.3754
#   Full set 95% CI: [0.3744, 0.3764]
#   Low-freq (<1%) Mean R²: 0.0089
#   Low-freq (<1%) 95% CI: [0.0084, 0.0095]
#   Rare (<0.1%) Mean R²: 0.0000
#   Rare (<0.1%) 95% CI: [0.0000, 0.0000]
# Method: UKBB_hclt_afr_combined
#   Full set Mean R²: 0.7016
#   Full set 95% CI: [0.6835, 0.7197]
#   Low-freq (<1%) Mean R²: 0.4101
#   Low-freq (<1%) 95% CI: [0.3796, 0.4407]
#   Rare (<0.1%) Mean R²: 0.1177
#   Rare (<0.1%) 95% CI: [0.0949, 0.1405]
# Method: UKBB_rbm_afr_combined
#   Full set Mean R²: 0.6593
#   Full set 95% CI: [0.6407, 0.6779]
#   Low-freq (<1%) Mean R²: 0.3834
#   Low-freq (<1%) 95% CI: [0.3521, 0.4147]
#   Rare (<0.1%) Mean R²: 0.1167
#   Rare (<0.1%) 95% CI: [0.0943, 0.1391]
# Method: UKBB_wgan_afr_combined
#   Full set Mean R²: 0.6679
#   Full set 95% CI: [0.6501, 0.6856]
#   Low-freq (<1%) Mean R²: 0.3878
#   Low-freq (<1%) 95% CI: [0.3577, 0.4179]
#   Rare (<0.1%) Mean R²: 0.1152
#   Rare (<0.1%) 95% CI: [0.0927, 0.1377]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9  # desired number of bins
all_methods = ['real', 'pc', 'hclt', 'rbm', 'wgan',]
all_colors = ['black', 'dodgerblue', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', 
    f'{my_method_name}', 'RBM', 'WGAN'
]
all_linestyles = ['--', '-', '-', '-', '-']

# --- Function to summarize bootstrap statistics ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = max(overall_mean - 1.96 * sem, 0)
    ci_upper = min(overall_mean + 1.96 * sem, 1)
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Load and filter data ---
method_data = {}
for method in all_methods:
    df = pd.read_csv(f'results/multi/8020_multi_{method}_b38_hum5_chr15_results.csv')
    
    # Remove MAF=0 variants
    df = df[df['MAF'] > 0].copy()
    df = df.reset_index(drop=True)

    # Fill missing R2 values
    r2_cols = [col for col in df.columns if col.startswith("R2")]
    df[r2_cols] = df[r2_cols].fillna(0)
    
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
    
    print(f"Method: {method}")
    summarize_bootstrap(df, boot_cols, "Full set")
    summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
    summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")
    
    method_data[method] = df

# --- Compute equal-count bins based on MAF ---
# Using quantiles ensures roughly equal SNP counts per bin
bin_edges = np.quantile(pd.concat([df['MAF'] for df in method_data.values()]), 
                        np.linspace(0, 1, num_bins + 1))
bin_centers = np.sqrt(bin_edges[:-1] * bin_edges[1:])  # geometric mean for log-style plot

# --- Plot each method with CI bands ---
plt.figure(figsize=(8,6))

for method_name, color, marker, label, linestyle in zip(
    all_methods, all_colors, all_markers, all_labels, all_linestyles
):
    df = method_data[method_name]
    boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
    
    # Assign bins
    bin_indices = np.digitize(df['MAF'], bin_edges) - 1
    bin_indices[bin_indices == num_bins] = num_bins - 1  # edge case

    mean_r2 = []
    ci_low = []
    ci_high = []

    for i in range(num_bins):
        in_bin = bin_indices == i
        if not np.any(in_bin):
            mean_r2.append(np.nan)
            ci_low.append(np.nan)
            ci_high.append(np.nan)
            continue

        # bootstrap values for this bin
        boot_values = df.loc[in_bin, boot_cols].values
        bin_means = np.nanmean(boot_values, axis=0)
        mean = np.mean(bin_means)
        sem = np.std(bin_means, ddof=1)
        ci = 1.96 * sem

        # clip CI to [0,1]
        mean_r2.append(mean)
        ci_low.append(max(mean - ci, 0))
        ci_high.append(min(mean + ci, 1))

    plt.plot(bin_centers, mean_r2, marker=marker, linestyle=linestyle, color=color, label=label)
    plt.fill_between(bin_centers, ci_low, ci_high, color=color, alpha=0.2)

# --- Formatting ---
plt.xscale('log')
plt.xticks([1e-3, 1e-2, 1e-1], [r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('MAF', fontsize=18)
plt.ylabel(r'Average $r^2$', fontsize=18)
plt.ylim(0,1)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=14)
plt.tight_layout()
plt.savefig("results/plots/b38_8020_multi_bootstrap_ci.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Method: real
#   Full set Mean R²: 0.7493
#   Full set 95% CI: [0.7453, 0.7532]
#   Low-freq (<1%) Mean R²: 0.6255
#   Low-freq (<1%) 95% CI: [0.6177, 0.6333]
#   Rare (<0.1%): No data
# Method: pc
#   Full set Mean R²: 0.5936
#   Full set 95% CI: [0.5894, 0.5978]
#   Low-freq (<1%) Mean R²: 0.3439
#   Low-freq (<1%) 95% CI: [0.3354, 0.3523]
#   Rare (<0.1%): No data
# Method: hclt
#   Full set Mean R²: 0.5147
#   Full set 95% CI: [0.5114, 0.5180]
#   Low-freq (<1%) Mean R²: 0.2151
#   Low-freq (<1%) 95% CI: [0.2086, 0.2217]
#   Rare (<0.1%): No data
# Method: rbm
#   Full set Mean R²: 0.5736
#   Full set 95% CI: [0.5696, 0.5777]
#   Low-freq (<1%) Mean R²: 0.3009
#   Low-freq (<1%) 95% CI: [0.2897, 0.3121]
#   Rare (<0.1%): No data
# Method: wgan
#   Full set Mean R²: 0.4740
#   Full set 95% CI: [0.4717, 0.4763]
#   Low-freq (<1%) Mean R²: 0.1195
#   Low-freq (<1%) 95% CI: [0.1158, 0.1232]
#   Rare (<0.1%): No data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9  # desired number of bins
all_methods = ['realeur', 'pc', 'hclt', 'rbm', 'wgan']
all_colors = ['black', 'dodgerblue', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', 
    f'{my_method_name}', 'RBM', 'WGAN'
]
all_linestyles = ['--', '-', '-', '-', '-']

# --- Function to summarize bootstrap statistics ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = max(overall_mean - 1.96 * sem, 0)
    ci_upper = min(overall_mean + 1.96 * sem, 1)
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Function to load data ---
def load_method_data(method_names, prefix="noneur", suffix=""):
    method_data = {}
    for method in method_names:
        if method == 'realeur':
            filename = f'results/multi/{prefix}_multi_{method}_b38_hum5_chr15_results.csv'
        else:
            filename = f'results/multi/{prefix}_multi_{method}{suffix}_b38_hum5_chr15_results.csv'
        df = pd.read_csv(filename)
        df = df[df['MAF'] > 0].copy()
        df = df.reset_index(drop=True)

        r2_cols = [col for col in df.columns if col.startswith("R2")]
        df[r2_cols] = df[r2_cols].fillna(0)
        boot_cols = [col for col in df.columns if col.startswith('R2_boot_')]

        print(f"Method: {method}{suffix}")
        summarize_bootstrap(df, boot_cols, "Full set")
        summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
        summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

        method_data[method] = df
    return method_data

# --- Compute bin edges ---
def compute_bin_edges(method_data, num_bins):
    all_maf = pd.concat([df['MAF'] for df in method_data.values()])
    bin_edges = np.quantile(all_maf, np.linspace(0, 1, num_bins + 1))
    bin_centers = np.sqrt(bin_edges[:-1] * bin_edges[1:])
    return bin_edges, bin_centers

# --- Plotting function ---
def plot_bootstrap(method_data, bin_edges, bin_centers, title, savefile, labels=None):
    if labels is None:
        labels = all_labels
    plt.figure(figsize=(8,6))
    for method_name, color, marker, label, linestyle in zip(
        all_methods, all_colors, all_markers, labels, all_linestyles
    ):
        df = method_data[method_name]
        boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
        bin_indices = np.digitize(df['MAF'], bin_edges) - 1
        bin_indices[bin_indices == num_bins] = num_bins - 1

        mean_r2, ci_low, ci_high = [], [], []
        for i in range(num_bins):
            in_bin = bin_indices == i
            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            mean = np.mean(bin_means)
            sem = np.std(bin_means, ddof=1)
            ci = 1.96 * sem
            mean_r2.append(mean)
            ci_low.append(max(mean - ci, 0))
            ci_high.append(min(mean + ci, 1))

        plt.plot(bin_centers, mean_r2, marker=marker, linestyle=linestyle, color=color, label=label)
        plt.fill_between(bin_centers, ci_low, ci_high, color=color, alpha=0.2)

    plt.xscale('log')
    plt.xticks([1e-3, 1e-2, 1e-1], [r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
    plt.yticks(fontsize=16)
    plt.xlabel('MAF', fontsize=18)
    plt.ylabel(r'Average $r^2$', fontsize=18)
    plt.ylim(0,1)
    # plt.title(title, fontsize=18)
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.legend(fontsize=14)
    plt.tight_layout()
    plt.savefig(savefile, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Original Non-EUR plot ---
method_data = load_method_data(all_methods, prefix="noneur")
bin_edges, bin_centers = compute_bin_edges(method_data, num_bins)
plot_bootstrap(method_data, bin_edges, bin_centers, "Non EUR AGs", "results/plots/b38_noneur_multi_bootstrap_ci.pdf")

# --- Combined Non-EUR plot ---
method_data_combined = load_method_data(all_methods, prefix="noneur", suffix="_combined")
bin_edges_combined, bin_centers_combined = compute_bin_edges(method_data_combined, num_bins)
plot_bootstrap(method_data_combined, bin_edges_combined, bin_centers_combined,
               "Non EUR AGs + Real EUR",
               "results/plots/b38_noneur_multi_bootstrap_ci_combined.pdf",
               labels=['Impute5', f'{my_method_name} (direct)', f'{my_method_name}', 'RBM', 'WGAN'])
# Out:
# Method: realeur
#   Full set Mean R²: 0.3384
#   Full set 95% CI: [0.3354, 0.3415]
#   Low-freq (<1%) Mean R²: 0.0457
#   Low-freq (<1%) 95% CI: [0.0423, 0.0490]
#   Rare (<0.1%): No data
# Method: pc
#   Full set Mean R²: 0.5933
#   Full set 95% CI: [0.5903, 0.5962]
#   Low-freq (<1%) Mean R²: 0.3391
#   Low-freq (<1%) 95% CI: [0.3348, 0.3435]
#   Rare (<0.1%): No data
# Method: hclt
#   Full set Mean R²: 0.5292
#   Full set 95% CI: [0.5271, 0.5314]
#   Low-freq (<1%) Mean R²: 0.2371
#   Low-freq (<1%) 95% CI: [0.2344, 0.2397]
#   Rare (<0.1%): No data
# Method: rbm
#   Full set Mean R²: 0.5648
#   Full set 95% CI: [0.5615, 0.5681]
#   Low-freq (<1%) Mean R²: 0.2955
#   Low-freq (<1%) 95% CI: [0.2874, 0.3037]
#   Rare (<0.1%): No data
# Method: wgan
#   Full set Mean R²: 0.4623
#   Full set 95% CI: [0.4587, 0.4659]
#   Low-freq (<1%) Mean R²: 0.1137
#   Low-freq (<1%) 95% CI: [0.1117, 0.1156]
#   Rare (<0.1%): No data
# Method: realeur_combined
#   Full set Mean R²: 0.3384
#   Full set 95% CI: [0.3354, 0.3415]
#   Low-freq (<1%) Mean R²: 0.0457
#   Low-freq (<1%) 95% CI: [0.0423, 0.0490]
#   Rare (<0.1%): No data
# Method: pc_combined
#   Full set Mean R²: 0.5835
#   Full set 95% CI: [0.5805, 0.5864]
#   Low-freq (<1%) Mean R²: 0.3306
#   Low-freq (<1%) 95% CI: [0.3231, 0.3382]
#   Rare (<0.1%): No data
# Method: hclt_combined
#   Full set Mean R²: 0.5481
#   Full set 95% CI: [0.5445, 0.5518]
#   Low-freq (<1%) Mean R²: 0.2656
#   Low-freq (<1%) 95% CI: [0.2555, 0.2757]
#   Rare (<0.1%): No data
# Method: rbm_combined
#   Full set Mean R²: 0.5838
#   Full set 95% CI: [0.5800, 0.5877]
#   Low-freq (<1%) Mean R²: 0.3288
#   Low-freq (<1%) 95% CI: [0.3206, 0.3370]
#   Rare (<0.1%): No data
# Method: wgan_combined
#   Full set Mean R²: 0.4944
#   Full set 95% CI: [0.4894, 0.4993]
#   Low-freq (<1%) Mean R²: 0.1619
#   Low-freq (<1%) 95% CI: [0.1550, 0.1688]
#   Rare (<0.1%): No data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Settings ---
num_bins = 9  # desired number of bins
all_methods = ['realeur', 'pc', 'hclt', 'rbm', 'wgan']
all_colors = ['black', 'dodgerblue', 'b', 'orange', 'g']
all_markers = ['o', 's', 's', '^', 'D']
all_labels = [
    'Impute5', f'{my_method_name} (direct)', 
    f'{my_method_name}', 'RBM', 'WGAN'
]
all_linestyles = ['--', '-', '-', '-', '-']

# --- Function to summarize bootstrap statistics ---
def summarize_bootstrap(df_subset, boot_cols, label):
    if df_subset.empty:
        print(f"  {label}: No data")
        return
    bootstrap_means = df_subset[boot_cols].mean(skipna=True)
    overall_mean = bootstrap_means.mean()
    sem = bootstrap_means.std(ddof=1)
    ci_lower = max(overall_mean - 1.96 * sem, 0)
    ci_upper = min(overall_mean + 1.96 * sem, 1)
    print(f"  {label} Mean R²: {overall_mean:.4f}")
    print(f"  {label} 95% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")

# --- Function to load data ---
def load_method_data(method_names, suffix=""):
    method_data = {}
    for method in method_names:
        if method == 'realeur':
            filename = f'results/multi/afr_multi_{method}_b38_hum5_chr15_results.csv'
        else:
            filename = f'results/multi/afr_multi_{method}{suffix}_b38_hum5_chr15_results.csv'
        df = pd.read_csv(filename)
        df = df[df['MAF'] > 0].copy()
        df = df.reset_index(drop=True)

        r2_cols = [col for col in df.columns if col.startswith("R2")]
        df[r2_cols] = df[r2_cols].fillna(0)
        boot_cols = [col for col in df.columns if col.startswith('R2_boot_')]

        print(f"Method: {method}{suffix}")
        summarize_bootstrap(df, boot_cols, "Full set")
        summarize_bootstrap(df[df['MAF'] < 0.01], boot_cols, "Low-freq (<1%)")
        summarize_bootstrap(df[df['MAF'] < 0.001], boot_cols, "Rare (<0.1%)")

        method_data[method] = df
    return method_data

# --- Compute bin edges from all methods ---
def compute_bin_edges(method_data, num_bins):
    all_maf = pd.concat([df['MAF'] for df in method_data.values()])
    bin_edges = np.quantile(all_maf, np.linspace(0, 1, num_bins + 1))
    bin_centers = np.sqrt(bin_edges[:-1] * bin_edges[1:])
    return bin_edges, bin_centers

# --- Plotting function ---
def plot_bootstrap(method_data, bin_edges, bin_centers, title, savefile, labels=None):
    if labels is None:
        labels = all_labels
    plt.figure(figsize=(8,6))
    for method_name, color, marker, label, linestyle in zip(
        all_methods, all_colors, all_markers, labels, all_linestyles
    ):
        df = method_data[method_name]
        boot_cols = [c for c in df.columns if c.startswith('R2_boot_')]
        bin_indices = np.digitize(df['MAF'], bin_edges) - 1
        bin_indices[bin_indices == num_bins] = num_bins - 1

        mean_r2, ci_low, ci_high = [], [], []
        for i in range(num_bins):
            in_bin = bin_indices == i
            if not np.any(in_bin):
                mean_r2.append(np.nan)
                ci_low.append(np.nan)
                ci_high.append(np.nan)
                continue
            boot_values = df.loc[in_bin, boot_cols].values
            bin_means = np.nanmean(boot_values, axis=0)
            mean = np.mean(bin_means)
            sem = np.std(bin_means, ddof=1)
            ci = 1.96 * sem
            mean_r2.append(mean)
            ci_low.append(max(mean - ci, 0))
            ci_high.append(min(mean + ci, 1))

        plt.plot(bin_centers, mean_r2, marker=marker, linestyle=linestyle, color=color, label=label)
        plt.fill_between(bin_centers, ci_low, ci_high, color=color, alpha=0.2)

    plt.xscale('log')
    plt.xticks([1e-3, 1e-2, 1e-1], [r"$10^{-3}$", r"$10^{-2}$", r"$10^{-1}$"], fontsize=16)
    plt.yticks(fontsize=16)
    plt.xlabel('MAF', fontsize=18)
    plt.ylabel(r'Average $r^2$', fontsize=18)
    plt.ylim(0,1)
    # plt.title(title, fontsize=18)
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.legend(fontsize=14)
    plt.tight_layout()
    plt.savefig(savefile, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Original plot ---
method_data = load_method_data(all_methods)
bin_edges, bin_centers = compute_bin_edges(method_data, num_bins)
plot_bootstrap(method_data, bin_edges, bin_centers, "AFR AGs", "results/plots/b38_afr_multi_bootstrap_ci.pdf")

# --- Combined plot ---
method_data_combined = load_method_data(all_methods, suffix="_combined")
bin_edges_combined, bin_centers_combined = compute_bin_edges(method_data_combined, num_bins)
plot_bootstrap(method_data_combined, bin_edges_combined, bin_centers_combined,
               "AFR AGs + Real EUR",
               "results/plots/b38_afr_multi_bootstrap_ci_combined.pdf",
               labels=['Impute5', f'{my_method_name} (direct)', f'{my_method_name}', 'RBM', 'WGAN'])
# Out:
# Method: realeur
#   Full set Mean R²: 0.2683
#   Full set 95% CI: [0.2639, 0.2726]
#   Low-freq (<1%) Mean R²: 0.0219
#   Low-freq (<1%) 95% CI: [0.0170, 0.0268]
#   Rare (<0.1%): No data
# Method: pc
#   Full set Mean R²: 0.5825
#   Full set 95% CI: [0.5741, 0.5908]
#   Low-freq (<1%) Mean R²: 0.3755
#   Low-freq (<1%) 95% CI: [0.3549, 0.3961]
#   Rare (<0.1%): No data
# Method: hclt
#   Full set Mean R²: 0.5456
#   Full set 95% CI: [0.5388, 0.5524]
#   Low-freq (<1%) Mean R²: 0.3168
#   Low-freq (<1%) 95% CI: [0.2994, 0.3342]
#   Rare (<0.1%): No data
# Method: rbm
#   Full set Mean R²: 0.5521
#   Full set 95% CI: [0.5425, 0.5616]
#   Low-freq (<1%) Mean R²: 0.3392
#   Low-freq (<1%) 95% CI: [0.3195, 0.3589]
#   Rare (<0.1%): No data
# Method: wgan
#   Full set Mean R²: 0.3672
#   Full set 95% CI: [0.3633, 0.3711]
#   Low-freq (<1%) Mean R²: 0.0819
#   Low-freq (<1%) 95% CI: [0.0778, 0.0859]
#   Rare (<0.1%): No data
# Method: realeur_combined
#   Full set Mean R²: 0.2683
#   Full set 95% CI: [0.2639, 0.2726]
#   Low-freq (<1%) Mean R²: 0.0219
#   Low-freq (<1%) 95% CI: [0.0170, 0.0268]
#   Rare (<0.1%): No data
# Method: pc_combined
#   Full set Mean R²: 0.5616
#   Full set 95% CI: [0.5523, 0.5708]
#   Low-freq (<1%) Mean R²: 0.3415
#   Low-freq (<1%) 95% CI: [0.3200, 0.3630]
#   Rare (<0.1%): No data
# Method: hclt_combined
#   Full set Mean R²: 0.5562
#   Full set 95% CI: [0.5483, 0.5642]
#   Low-freq (<1%) Mean R²: 0.3253
#   Low-freq (<1%) 95% CI: [0.3070, 0.3435]
#   Rare (<0.1%): No data
# Method: rbm_combined
#   Full set Mean R²: 0.5631
#   Full set 95% CI: [0.5526, 0.5736]
#   Low-freq (<1%) Mean R²: 0.3502
#   Low-freq (<1%) 95% CI: [0.3299, 0.3705]
#   Rare (<0.1%): No data
# Method: wgan_combined
#   Full set Mean R²: 0.4069
#   Full set 95% CI: [0.3984, 0.4155]
#   Low-freq (<1%) Mean R²: 0.1014
#   Low-freq (<1%) 95% CI: [0.0927, 0.1101]
#   Rare (<0.1%): No data
